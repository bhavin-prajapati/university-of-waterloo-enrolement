# %% [markdown]
# # Group Assignment: University of Waterloo Enrolement

# %% [markdown]
# ### Group 1:
# - Prajapati, Bhavin, b4prajap, bhavin.prajapati@gmail.com
# - Mathieu, Andrew, amathieu
# - Izarra-Jacome, Amaru, aizarraj
# - Ho, Anson, a73ho
# - Uy, April, a4uy

# %% [markdown]
# Group 1 - Project Proposal: https://docs.google.com/document/d/16ejedVsZR0gxWm2Cq63TXL4umfFqIYn5Cb2SG7QoKM0/edit?usp=drive_link
#
# Group 1 - Report: https://docs.google.com/document/d/1-T-YXas5H3eGv0K0VpudtBwtbgvIuvQKme0crm-Ew1Q/edit?usp=drive_link

# %% [markdown]
# # Dataset
# <a href="https://www.kaggle.com/datasets/chromaa/university-of-waterloo-enrolement" data-toc-modified-id="Bicycle-Thefts-City-of-Toronto-Open-Data-Portal">University of Waterloo Enrolement</a>
# <br>
# URL: https://www.kaggle.com/datasets/chromaa/university-of-waterloo-enrolement

# %% [markdown]
# # Questions
# ### Who is going to be enrolling in courses?
# - Analyze the undergraduate/graduate students and coop/regular.
# - Determine students enrolment based on study year (eg. 1st, 2nd, etc)
# ### What programs are students enrolling into?
# - Analyze the diploma/bachelors/masters/doctoral enrolment.
# - Assess the different programs and faculties for student enrolment.
# ### Where are students enrolling?
# - Analyze which campus, UW or St. Jerome's University
# ### When are students enrolling?
# - Analyze which study term (eg. Spring, Summer, Fall, Winter)

# %% [markdown]
# # Problem
# We want to analyze our dataset (waterloo-enrolement-2024.csv) using Apache Spark's MLlib with a given set of paramters which include the following as lists:
# - Fiscal Year: 2016/17, 2017/18, ..., 2023/24
# - Career: Undergraduate, Graduate
# - Study Year: 1, 2, 3, 4, N, D, M
# - Program Level: Diploma, Bachelors, Masters, Doctoral
# - Faculty: ENG, ARTS, ENV, HEA, MATH, SCI, THL
# - Program Grouping: Accounting, Applied Economics, Philosophy, Engineering, etc.
# - Campus: University of Waterloo, St. Jerome's University, Conrad Grebel University College
# - Term Type: Spring term, Fall term, Winter term, etc.
# - Coop Regular: Regular, Coop
# - Attendance: Full-Time, Part-Time
# - Visa: Canadian, Canadian Permanent Resident, International
#
# The solution should allow configuration of some or all the parameters and use them to train a model to predict student enrolment (Student Headcounts).

# %% [markdown]
# ## Import Libraries
# First we will import all the libraries we need to do our analysis

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, sum as spark_sum, count, avg, desc, log1p, expm1, when, greatest, lit, substring
from pyspark.ml.feature import StringIndexer, VectorAssembler, OneHotEncoder
from pyspark.ml.regression import RandomForestRegressor, GBTRegressor, LinearRegression
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Create Spark Session

# %%
import os
os.environ['JAVA_HOME'] = '/usr/local/Cellar/openjdk@17/17.0.18/libexec/openjdk.jdk/Contents/Home'

spark = SparkSession.builder \
    .appName('UW Enrolement Prediction') \
    .master('local[2]') \
    .config('spark.driver.memory', '8g') \
    .config('spark.driver.extraJavaOptions', '-Xss4m') \
    .config('spark.executor.extraJavaOptions', '-Xss4m') \
    .getOrCreate()

spark.sparkContext.setLogLevel('ERROR')
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/29 14:54:51 WARN Utils: Your hostname, Bhavins-MacBook-Pro-2.local, resolves to a loopback address: 127.0.0.1; using 10.0.0.207 instead (on interface en0)
# 26/03/29 14:54:51 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/29 14:54:52 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## Load and Explore the Dataset

# %%
df = spark.read.csv('waterloo-enrolement-2024.csv', header=True, inferSchema=True)

# Drop rows with any null values
df = df.dropna()

print(f'Total rows: {df.count()}')
print(f'Total columns: {len(df.columns)}')
print()
df.printSchema()
# Out:
# Total rows: 61273
# Total columns: 13
#
# root
#  |-- Fiscal Year: string (nullable = true)
#  |-- Term Type: string (nullable = true)
#  |-- Career: string (nullable = true)
#  |-- Program Level: string (nullable = true)
#  |-- Study Year: string (nullable = true)
#  |-- Campus: string (nullable = true)
#  |-- Faculty (group): string (nullable = true)
#  |-- Program Grouping: string (nullable = true)
#  |-- Coop Regular: string (nullable = true)
#  |-- Work Term: string (nullable = true)
#  |-- Attendance: string (nullable = true)
#  |-- Visa Status: string (nullable = true)
#  |-- Student Headcounts: integer (nullable = true)

# %%
df.show(10, truncate=False)
# Out:
# +-----------+---------+--------+-------------+----------+----------------------+---------------+-----------------------------+------------+-------------+----------+---------------------------+------------------+
# |Fiscal Year|Term Type|Career  |Program Level|Study Year|Campus                |Faculty (group)|Program Grouping             |Coop Regular|Work Term    |Attendance|Visa Status                |Student Headcounts|
# +-----------+---------+--------+-------------+----------+----------------------+---------------+-----------------------------+------------+-------------+----------+---------------------------+------------------+
# |2016/17    |Fall term|Graduate|Diploma      |N         |University of Waterloo|ENG            |Business and Entrepreneurship|Regular     |Academic Term|Part-Time |Canadian Permanent Resident|1                 |
# ...

# %%
# Summary statistics for the target variable
df.select('Student Headcounts').describe().show()
# Out:
# +-------+------------------+
# |summary|Student Headcounts|
# +-------+------------------+
# |  count|             61273|
# |   mean|13.955869632627747|
# | stddev| 30.19764686553697|
# |    min|                 1|
# |    max|               552|
# +-------+------------------+

# %% [markdown]
# ## Exploratory Data Analysis
# Explore the distinct values for each categorical column.

# %%
# Distinct values per column
for c in df.columns:
    distinct_count = df.select(c).distinct().count()
    print(f'{c}: {distinct_count} distinct values')
# Out:
# Fiscal Year: 8 distinct values
# Term Type: 3 distinct values
# Career: 2 distinct values
# Program Level: 6 distinct values
# Study Year: 8 distinct values
# Campus: 6 distinct values
# Faculty (group): 11 distinct values
# Program Grouping: 144 distinct values
# Coop Regular: 2 distinct values
# Work Term: 2 distinct values
# Attendance: 3 distinct values
# Visa Status: 3 distinct values
# Student Headcounts: 337 distinct values

# %%
# Enrolment by Career (Undergraduate vs Graduate)
career_df = df.groupBy('Career').agg(
    spark_sum('Student Headcounts').alias('Total Headcounts'),
    count('*').alias('Record Count')
).orderBy(desc('Total Headcounts'))
career_df.show()
# Out:
# +-------------+----------------+------------+
# |       Career|Total Headcounts|Record Count|
# +-------------+----------------+------------+
# |Undergraduate|          716370|       50015|
# |     Graduate|          138748|       11258|
# +-------------+----------------+------------+

# %%
# Enrolment by Faculty
faculty_df = df.groupBy('Faculty (group)').agg(
    spark_sum('Student Headcounts').alias('Total Headcounts')
).orderBy(desc('Total Headcounts'))

faculty_pd = faculty_df.toPandas().dropna(subset=['Faculty (group)'])
plt.figure(figsize=(10, 5))
plt.bar(faculty_pd['Faculty (group)'].astype(str), faculty_pd['Total Headcounts'])
plt.xlabel('Faculty')
plt.ylabel('Total Headcounts')
plt.title('Total Enrolment by Faculty')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Enrolment by Term Type
term_df = df.groupBy('Term Type').agg(
    spark_sum('Student Headcounts').alias('Total Headcounts')
).orderBy(desc('Total Headcounts'))
term_df.show()
# Out:
# +-----------+----------------+
# |  Term Type|Total Headcounts|
# +-----------+----------------+
# |  Fall term|          325000|
# |Winter term|          312894|
# |Spring term|          217224|
# +-----------+----------------+

# %%
# Enrolment by Fiscal Year
year_df = df.groupBy('Fiscal Year').agg(
    spark_sum('Student Headcounts').alias('Total Headcounts')
).orderBy('Fiscal Year')

year_pd = year_df.toPandas().dropna(subset=['Fiscal Year'])
plt.figure(figsize=(10, 5))
plt.plot(year_pd['Fiscal Year'].astype(str), year_pd['Total Headcounts'], marker='o')
plt.xlabel('Fiscal Year')
plt.ylabel('Total Headcounts')
plt.title('Total Enrolment by Fiscal Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Enrolment by Coop vs Regular
coop_df = df.groupBy('Coop Regular').agg(
    spark_sum('Student Headcounts').alias('Total Headcounts')
).orderBy(desc('Total Headcounts'))
coop_df.show()
# Out:
# +------------+----------------+
# |Coop Regular|Total Headcounts|
# +------------+----------------+
# |       Co-op|          517106|
# |     Regular|          338012|
# +------------+----------------+

# %%
# Enrolment by Campus
campus_df = df.groupBy('Campus').agg(
    spark_sum('Student Headcounts').alias('Total Headcounts')
).orderBy(desc('Total Headcounts'))
campus_df.show(truncate=False)
# Out:
# +--------------------------------+----------------+
# |Campus                          |Total Headcounts|
# +--------------------------------+----------------+
# |University of Waterloo          |831903          |
# |Renison University College      |12168           |
# |St. Jerome's University         |10171           |
# |Conrad Grebel University College|629             |
# |Online - Renison                |168             |
# |Online                          |79              |
# +--------------------------------+----------------+

# %% [markdown]
# ## Configurable Parameters
# Configure which parameter values to include when training the model. Set any parameter to `None` to include all values, or provide a list to filter to specific values.

# %%
# ====================================================================
# CONFIGURABLE PARAMETERS
# Set any parameter to None to include ALL values for that column.
# Otherwise, provide a list of values to filter on.
# ====================================================================

config = {
    'Fiscal Year':       None,  # e.g. ['2022/23', '2023/24']
    'Career':            None,  # e.g. ['Undergraduate']
    'Study Year':        None,  # e.g. ['1', '2', '3', '4']
    'Program Level':     None,  # e.g. ['Bachelors', 'Masters']
    'Faculty (group)':   None,  # e.g. ['ENG', 'MATH']
    'Program Grouping':  None,  # e.g. ['Computer Science', 'Engineering']
    'Campus':            None,  # e.g. ['University of Waterloo']
    'Term Type':         None,  # e.g. ['Fall term', 'Winter term']
    'Coop Regular':      None,  # e.g. ['Coop']
    'Attendance':        None,  # e.g. ['Full-Time']
    'Visa Status':       None,  # e.g. ['Canadian', 'International']
}

# Apply filters based on configuration
filtered_df = df
for col_name, values in config.items():
    if values is not None:
        filtered_df = filtered_df.filter(col(col_name).isin(values))

print(f'Rows after filtering: {filtered_df.count()} (out of {df.count()})')
# Out:
# Rows after filtering: 61273 (out of 61273)

# %% [markdown]
# ## Data Preprocessing
# Encode all categorical features using StringIndexer and OneHotEncoder, then assemble them into a feature vector.

# %%
# Define categorical feature columns (all columns except the target)
categorical_cols = [c for c in filtered_df.columns if c != 'Student Headcounts']

# Drop rows with null target
filtered_df = filtered_df.dropna(subset=['Student Headcounts'])

# Feature engineering: extract numeric year from 'Fiscal Year' (e.g. '2016/17' -> 2016)
# This lets models capture year-over-year enrollment trends as a continuous feature
filtered_df = filtered_df.withColumn('numeric_year', substring(col('Fiscal Year'), 1, 4).cast('double'))

# Build StringIndexer and OneHotEncoder stages for each categorical column
indexers = []
encoders = []
encoded_cols = []

for c in categorical_cols:
    idx_col = c + '_idx'
    ohe_col = c + '_ohe'
    indexers.append(StringIndexer(inputCol=c, outputCol=idx_col, handleInvalid='keep'))
    encoders.append(OneHotEncoder(inputCol=idx_col, outputCol=ohe_col))
    encoded_cols.append(ohe_col)

# Assemble all encoded features + numeric year into a single vector
assembler = VectorAssembler(inputCols=encoded_cols + ['numeric_year'], outputCol='features')

print(f'Categorical columns: {categorical_cols}')
print(f'Number of feature columns: {len(categorical_cols)} categorical + 1 numeric (numeric_year)')
# Out:
# Categorical columns: ['Fiscal Year', 'Term Type', 'Career', 'Program Level', 'Study Year', 'Campus', 'Faculty (group)', 'Program Grouping', 'Coop Regular', 'Work Term', 'Attendance', 'Visa Status']
# Number of feature columns: 12 categorical + 1 numeric (numeric_year)

# %% [markdown]
# ## Train/Test Split

# %%
# Rename target column and apply log1p transform to handle right-skewed distribution
# (mean ~14, stddev ~30, max 552 — highly skewed count data)
# log1p(x) = log(1+x) safely handles zero values; we'll inverse with expm1 after prediction
model_df = filtered_df.withColumn('label', log1p(col('Student Headcounts').cast('double')))

# Keep original label for evaluation after inverse-transform
model_df = model_df.withColumn('original_label', col('Student Headcounts').cast('double'))

# Split data: 80% train, 20% test
train_df, test_df = model_df.randomSplit([0.8, 0.2], seed=42)

print(f'Training set size: {train_df.count()}')
print(f'Test set size: {test_df.count()}')
# Out:
# Training set size: 49087
# Test set size: 12186

# %% [markdown]
# ## Model Training with Cross-Validation
# We train three regression models using MLlib with CrossValidator-based hyperparameter tuning:
# 1. **Linear Regression** — tuning regParam and elasticNetParam
# 2. **Random Forest Regressor** — tuning numTrees and maxDepth
# 3. **Gradient-Boosted Tree Regressor** — tuning maxIter, maxDepth, and stepSize
#
# Models are trained on log-transformed labels. Predictions are inverse-transformed with expm1() and clipped to a minimum of 1 (headcounts must be positive).

# %%
# Define models and their hyperparameter grids for CrossValidator tuning
lr = LinearRegression(featuresCol='features', labelCol='label', maxIter=100)
lr_grid = ParamGridBuilder() \
    .addGrid(lr.regParam, [0.001, 0.01, 0.1]) \
    .addGrid(lr.elasticNetParam, [0.0, 0.5, 1.0]) \
    .build()

rf = RandomForestRegressor(featuresCol='features', labelCol='label', featureSubsetStrategy='sqrt', maxBins=150, seed=42)
rf_grid = ParamGridBuilder() \
    .addGrid(rf.numTrees, [200]) \
    .addGrid(rf.maxDepth, [10, 15]) \
    .build()

gbt = GBTRegressor(featuresCol='features', labelCol='label', subsamplingRate=0.8, maxBins=150, seed=42)
gbt_grid = ParamGridBuilder() \
    .addGrid(gbt.maxIter, [100]) \
    .addGrid(gbt.maxDepth, [5, 8]) \
    .addGrid(gbt.stepSize, [0.05, 0.1]) \
    .build()

# Two preprocessing strategies:
#
# 1. OHE pipeline for Linear Regression — linear models need explicit binary features.
#
# 2. Index-only pipeline for tree-based models (RF, GBT).
#    Trees handle indexed categoricals natively via splits. OHE actually hurts them:
#    - Each OHE column can only split on 0 vs 1, losing the ability to group categories
#    - High-cardinality columns (Program Grouping: 144 values) create ~143 sparse columns
#    - Trees need far more depth to capture the same information
#    Using indices directly gives each categorical ONE feature that the tree can split
#    at any point, dramatically improving accuracy and speed.
ohe_stages = indexers + encoders + [assembler]

indexed_cols = [c + '_idx' for c in categorical_cols]
assembler_idx = VectorAssembler(inputCols=indexed_cols + ['numeric_year'], outputCol='features')
tree_stages = indexers + [assembler_idx]

models = {
    'Linear Regression':      (lr,  lr_grid,  ohe_stages),
    'Random Forest':          (rf,  rf_grid,  tree_stages),
    'Gradient-Boosted Trees': (gbt, gbt_grid, tree_stages),
}

# Evaluator for CrossValidator (uses log-space RMSE for tuning)
cv_evaluator = RegressionEvaluator(labelCol='label', predictionCol='prediction', metricName='rmse')

# Evaluators for final metrics (on original scale after inverse-transform)
evaluator_rmse = RegressionEvaluator(labelCol='original_label', predictionCol='final_prediction', metricName='rmse')
evaluator_r2 = RegressionEvaluator(labelCol='original_label', predictionCol='final_prediction', metricName='r2')
evaluator_mae = RegressionEvaluator(labelCol='original_label', predictionCol='final_prediction', metricName='mae')

# Cache training data to avoid recomputing it for every CV fold
train_df.cache()
train_df.count()  # materialize the cache

# Train and evaluate each model with 3-fold cross-validation
results = {}
trained_models = {}

for name, (model, grid, stages) in models.items():
    print(f'Training {name} with 3-fold CV...')
    pipeline = Pipeline(stages=stages + [model])

    cv = CrossValidator(
        estimator=pipeline,
        estimatorParamMaps=grid,
        evaluator=cv_evaluator,
        numFolds=3,
        parallelism=2,
        seed=42
    )

    cv_model = cv.fit(train_df)
    predictions = cv_model.transform(test_df)

    # Inverse-transform predictions from log-space back to original scale
    # and clip to minimum of 1 (headcounts must be positive)
    predictions = predictions.withColumn(
        'final_prediction',
        greatest(expm1(col('prediction')), lit(1.0))
    )

    rmse = evaluator_rmse.evaluate(predictions)
    r2 = evaluator_r2.evaluate(predictions)
    mae = evaluator_mae.evaluate(predictions)

    results[name] = {'RMSE': rmse, 'R2': r2, 'MAE': mae}
    trained_models[name] = cv_model

    print(f'  RMSE: {rmse:.4f}')
    print(f'  R\u00b2:   {r2:.4f}')
    print(f'  MAE:  {mae:.4f}')
    print()

train_df.unpersist()
# Out:
# Training Linear Regression with 3-fold CV...
#   RMSE: 27.4351
#   R²:   0.2033
#   MAE:  10.4167
#
# Training Random Forest with 3-fold CV...
#   RMSE: 18.5091
#   R²:   0.6374
#   MAE:  6.4850
#
# Training Gradient-Boosted Trees with 3-fold CV...
# [Stage 21312:===========================>                           (1 + 1) / 2]
#   RMSE: 12.6811
#   R²:   0.8298
#   MAE:  4.6121
# DataFrame[Fiscal Year: string, Term Type: string, Career: string, Program Level: string, Study Year: string, Campus: string, Faculty (group): string, Program Grouping: string, Coop Regular: string, Work Term: string, Attendance: string, Visa Status: string, Student Headcounts: int, numeric_year: double, label: double, original_label: double]

# %% [markdown]
# ## Model Comparison

# %%
# Compare models side by side
results_pd = pd.DataFrame(results).T
results_pd.index.name = 'Model'
print(results_pd.to_string())

# Plot comparison
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

metrics = ['RMSE', 'R2', 'MAE']
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']

for i, metric in enumerate(metrics):
    axes[i].bar(results_pd.index, results_pd[metric], color=colors[i])
    axes[i].set_title(metric)
    axes[i].set_ylabel(metric)
    axes[i].tick_params(axis='x', rotation=30)

plt.suptitle('Model Comparison', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
#                              RMSE        R2        MAE
# Model
# Linear Regression       27.435116  0.203268  10.416704
# Random Forest           18.509076  0.637366   6.485036
# Gradient-Boosted Trees  12.681073  0.829780   4.612107

# %% [markdown]
# ## Best Model - Predictions vs Actuals
# Select the best model based on R² and visualize its predictions.

# %%
# Select best model by R²
best_model_name = max(results, key=lambda k: results[k]['R2'])
best_model = trained_models[best_model_name]

print(f'Best model: {best_model_name}')
print(f'  R²:   {results[best_model_name]["R2"]:.4f}')
print(f'  RMSE: {results[best_model_name]["RMSE"]:.4f}')
print(f'  MAE:  {results[best_model_name]["MAE"]:.4f}')
# Out:
# Best model: Gradient-Boosted Trees
#   R²:   0.8298
#   RMSE: 12.6811
#   MAE:  4.6121

# %% [markdown]
# ## Save Trained Models
# Save the best pipeline model for each algorithm (including preprocessing stages) to disk so they can be loaded later by an API.
# A metadata JSON file is also written with evaluation metrics and the name of the best model.

# %%
import os, json as _json, shutil

MODELS_DIR = 'models'

# Clean previous run
if os.path.exists(MODELS_DIR):
    shutil.rmtree(MODELS_DIR)
os.makedirs(MODELS_DIR, exist_ok=True)

# Save each model's best pipeline (from CrossValidator) to its own directory.
# cv_model.bestModel is a PipelineModel that includes all preprocessing +
# the trained regressor, so it can transform raw input data end-to-end.
saved_paths = {}
for name, cv_model in trained_models.items():
    safe_name = name.lower().replace(' ', '_').replace('-', '_')
    model_path = os.path.join(MODELS_DIR, safe_name)
    cv_model.bestModel.save(model_path)
    saved_paths[name] = model_path
    print(f'Saved {name} -> {model_path}')

# Write metadata (metrics + best model) so an API can discover which model to load
metadata = {
    'best_model': best_model_name,
    'models': {}
}
for name in results:
    safe_name = name.lower().replace(' ', '_').replace('-', '_')
    metadata['models'][name] = {
        'path': saved_paths[name],
        'RMSE': results[name]['RMSE'],
        'R2': results[name]['R2'],
        'MAE': results[name]['MAE'],
    }

metadata_path = os.path.join(MODELS_DIR, 'metadata.json')
with open(metadata_path, 'w') as f:
    _json.dump(metadata, f, indent=2)

print(f'\nMetadata written to {metadata_path}')
print(f'Best model: {best_model_name}')
# Out:
# Saved Linear Regression -> models/linear_regression
# Saved Random Forest -> models/random_forest
# Saved Gradient-Boosted Trees -> models/gradient_boosted_trees
#
# Metadata written to models/metadata.json
# Best model: Gradient-Boosted Trees

# %%
# Predictions vs Actuals scatter plot for all 3 models
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

for ax, (name, cv_model) in zip(axes, trained_models.items()):
    preds = cv_model.transform(test_df)
    preds = preds.withColumn(
        'final_prediction',
        greatest(expm1(col('prediction')), lit(1.0))
    )
    pred_pd = preds.select('original_label', 'final_prediction').toPandas()

    ax.scatter(pred_pd['original_label'], pred_pd['final_prediction'], alpha=0.3, s=10)

    max_val = max(pred_pd['original_label'].max(), pred_pd['final_prediction'].max())
    ax.plot([0, max_val], [0, max_val], 'r--', linewidth=2, label='Perfect Prediction')

    ax.set_xlabel('Actual Headcounts')
    ax.set_ylabel('Predicted Headcounts')
    r2 = results[name]['R2']
    rmse = results[name]['RMSE']
    ax.set_title(f'{name}\nR²={r2:.4f}  RMSE={rmse:.1f}')
    ax.legend(loc='upper left')

plt.suptitle('Predictions vs Actuals — All Models', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Importance
# Display feature importance for the Random Forest model.

# %%
# Get feature importance from the Random Forest model
rf_pipeline = trained_models['Random Forest'].bestModel
rf_model = rf_pipeline.stages[-1]  # Last stage is the regressor

importances = rf_model.featureImportances.toArray()

# With indexed features (no OHE), each categorical is exactly 1 feature.
# Feature order matches: categorical_cols + ['numeric_year']
feature_names = categorical_cols + ['numeric_year']
col_importance = dict(zip(feature_names, importances))

# Sort and plot
imp_pd = pd.Series(col_importance).sort_values(ascending=True)

plt.figure(figsize=(10, 6))
imp_pd.plot(kind='barh')
plt.xlabel('Feature Importance')
plt.title('Feature Importance by Column (Random Forest)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Answering the Research Questions

# %%
# Q1: Who is enrolling? - Undergraduate vs Graduate, Coop vs Regular, by Study Year
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# By Career
career_pd = df.groupBy('Career').agg(spark_sum('Student Headcounts').alias('Total')).orderBy(desc('Total')).toPandas()
axes[0].bar(career_pd['Career'], career_pd['Total'])
axes[0].set_title('Enrolment by Career')
axes[0].set_ylabel('Total Headcounts')
axes[0].tick_params(axis='x', rotation=45)

# By Coop/Regular
coop_pd = df.groupBy('Coop Regular').agg(spark_sum('Student Headcounts').alias('Total')).orderBy(desc('Total')).toPandas()
axes[1].bar(coop_pd['Coop Regular'], coop_pd['Total'])
axes[1].set_title('Enrolment by Coop/Regular')
axes[1].set_ylabel('Total Headcounts')
axes[1].tick_params(axis='x', rotation=45)

# By Study Year
year_pd = df.groupBy('Study Year').agg(spark_sum('Student Headcounts').alias('Total')).orderBy(desc('Total')).toPandas()
axes[2].bar(year_pd['Study Year'], year_pd['Total'])
axes[2].set_title('Enrolment by Study Year')
axes[2].set_ylabel('Total Headcounts')
axes[2].tick_params(axis='x', rotation=45)

fig.suptitle('Q1: Who is going to be enrolling?', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Q2: What programs are students enrolling into?
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# By Program Level
pl_pd = df.groupBy('Program Level').agg(spark_sum('Student Headcounts').alias('Total')).orderBy(desc('Total')).toPandas()
axes[0].barh(pl_pd['Program Level'], pl_pd['Total'])
axes[0].set_title('By Program Level')
axes[0].set_xlabel('Total Headcounts')
axes[0].invert_yaxis()

# By Faculty
fac_pd = df.groupBy('Faculty (group)').agg(spark_sum('Student Headcounts').alias('Total')).orderBy(desc('Total')).toPandas()
axes[1].barh(fac_pd['Faculty (group)'], fac_pd['Total'])
axes[1].set_title('By Faculty')
axes[1].set_xlabel('Total Headcounts')
axes[1].invert_yaxis()

# Top 15 Program Groupings
pg_pd = df.groupBy('Program Grouping').agg(spark_sum('Student Headcounts').alias('Total')).orderBy(desc('Total')).limit(15).toPandas()
axes[2].barh(pg_pd['Program Grouping'], pg_pd['Total'])
axes[2].set_title('Top 15 Program Groupings')
axes[2].set_xlabel('Total Headcounts')
axes[2].invert_yaxis()

fig.suptitle('Q2: What programs are students enrolling into?', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Q3: Where are students enrolling?
campus_pd = df.groupBy('Campus').agg(spark_sum('Student Headcounts').alias('Total')).orderBy(desc('Total')).toPandas()

plt.figure(figsize=(10, 5))
plt.barh(campus_pd['Campus'], campus_pd['Total'])
plt.xlabel('Total Headcounts')
plt.title('Q3: Where are students enrolling?', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Q4: When are students enrolling?
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# By Term Type
term_pd = df.groupBy('Term Type').agg(spark_sum('Student Headcounts').alias('Total')).orderBy(desc('Total')).toPandas()
axes[0].bar(term_pd['Term Type'], term_pd['Total'])
axes[0].set_title('By Term Type')
axes[0].set_ylabel('Total Headcounts')
axes[0].tick_params(axis='x', rotation=45)

# By Fiscal Year (stacked by term)
fy_pd = df.groupBy('Fiscal Year', 'Term Type').agg(
    spark_sum('Student Headcounts').alias('Total')
).orderBy('Fiscal Year', 'Term Type').toPandas()
pivot = fy_pd.pivot(index='Fiscal Year', columns='Term Type', values='Total').fillna(0)
pivot.plot(kind='bar', stacked=True, ax=axes[1])
axes[1].set_title('By Fiscal Year & Term')
axes[1].set_ylabel('Total Headcounts')
axes[1].tick_params(axis='x', rotation=45)
axes[1].legend(title='Term', bbox_to_anchor=(1.0, 1.0))

fig.suptitle('Q4: When are students enrolling?', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Cleanup

# %%
spark.stop()
print('Spark session stopped.')
# Out:
# Spark session stopped.
